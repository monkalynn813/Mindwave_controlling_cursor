# %%
import numpy as np
import matplotlib.pyplot as plt
import ref_streaming as waves

# %%
channels_num = 8
fs = 250
alpha_band = (8,13)

br = waves.Brain_waves(None, channels_num, fs)
band_vals, time = br.read_csv_waves('data/test.csv', alpha_band)
plt.plot(time,band_vals[6])
plt.show()
